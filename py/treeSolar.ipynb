# %%
import numpy as np
import pandas as pd
import boto3
from botocore import UNSIGNED
from botocore.client import Config
import json
from pyproj import Transformer
import math
import shapely
from time import sleep
import datetime
import panel as pn

# %matplotlib tk
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import matplotlib.path as mpltPath
import matplotlib.patches as patches
import os

from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from scipy.spatial.distance import pdist
from scipy import ndimage as ndi
from skimage import feature

import pytz
from tzwhere import tzwhere
from pysolar.solar import get_azimuth, get_altitude, radiation

#!pip install "laspy[lazrs,laszip]" #ensure laz handler installed
import laspy 
from treeSolarTools import *

# %%
#show the national Lidar map for user selection

lon,lat = 0,0
fig = plt.figure(figsize=(15,15), dpi=150, constrained_layout=True)
ax1 = fig.add_subplot(111)

df = pd.read_csv('2015StreetTreesCensus_TREES.csv')

def onclick(event):
    global lon
    global lat
    lon, lat = event.xdata, event.ydata
    print(lat, lon)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
#print(cid)
features = readGeoJSON('lidarBoundaries.geojson')
for feature in features:
    points,name = footprintPointsFromGeoJSON(feature)
    path = mpltPath.Path(points)
    patch = patches.PathPatch(path, facecolor='whitesmoke', lw=0.3)
    ax1.add_patch(patch)
    
#plt.scatter(df['x_sp'],df['y_sp'],s=0.05,c='green')

ratio = 1.2
xMin, xMax = ax1.get_xlim()
yMin, yMax = ax1.get_ylim()
ax1.set_aspect( abs( ( xMax - xMin ) / ( yMin - yMax ) ) * ratio )
ax1.set_xlim(-132, -62)   
ax1.set_ylim(22, 52)

plt.show()
# Out:
# 43.947858145336795 -78.14173597323366
# 40.6771583719837 -73.88925769008843

# %%
#lat,lon = 42.317398154639406, -83.08877069697685 # Detroit test
#lat,lon = 42.44963137138453, -76.47201539955707 # Cornell Botanic Gardens
#lat,lon = 37.126779357226944, -122.12067957145447 #Boulder Creek, CA

lidarArea = None
features = readGeoJSON('lidarBoundaries.geojson')
for feature in features:
    points,name = footprintPointsFromGeoJSON(feature)
    poly = shapely.geometry.Polygon(points)
    point = shapely.geometry.Point(lon,lat)
    if poly.intersects(point):
        lidarArea = '{}/'.format(name)
if lidarArea == None:
    print('Lidar not found for this area, please enter another lat,lon.')
else:
    print('Lidar found for: ',lidarArea)
    
#refine location selection with tree census map for NYC

if lidarArea == 'NY_NewYorkCity/':
    ix,iy = 0,0
    fig = plt.figure(figsize=(15,15), dpi=150, constrained_layout=True)
    ax1 = fig.add_subplot(111)

    df = pd.read_csv('2015StreetTreesCensus_TREES.csv')

    def onclick(event):
        global ix
        global iy
        ix, iy = event.xdata, event.ydata
        print(ix, iy)

    cid = fig.canvas.mpl_connect('button_press_event', onclick)
    #print(cid)
    plt.scatter(df['x_sp'],df['y_sp'],s=0.05,c='green')

    ratio = 1.0
    xMin, xMax = ax1.get_xlim()
    yMin, yMax = ax1.get_ylim()
    ax1.set_aspect( abs( ( xMax - xMin ) / ( yMin - yMax ) ) * ratio )

    plt.show()

else:
    ix,iy = 0,0
# Out:
# Lidar found for:  NY_NewYorkCity/
# 974100.9521937321 206554.0125270538
# 979864.4616359381 187114.23166126764
# 988341.8580730688 184738.56656391674

# %%
# S3 retrieve block

if ix != 0 and iy != 0:
    transformer = Transformer.from_crs("epsg:2263", "epsg:4326")
    lat, lon = transformer.transform(ix, iy)
    print(lat,lon)
else:
    pass
boxSize = 100

lidar_df = stackTiles(lat,lon,boxSize,prefix=lidarArea)

xmean = lidar_df['X'].mean()
ymean = lidar_df['Y'].mean()
zmean = lidar_df['Z'].mean()

singleReturns = lidar_df[lidar_df['number_of_returns'] - lidar_df['return_number'] == 0 ]
multipleReturns = lidar_df[lidar_df['number_of_returns'] - lidar_df['return_number'] > 0 ]

fig = plt.figure(figsize=(15,225), dpi=300, constrained_layout=True)
ax1 = fig.add_subplot(1, 1, 1, projection='3d') ############         
#ax1.scatter3D(lidar_df['X'], lidar_df['Y'], lidar_df['Z'], zdir='z', s=0.01, c=lidar_df['intens'], cmap='bone', marker='+', depthshade=True)
ax1.scatter3D(singleReturns['X'], singleReturns['Y'], singleReturns['Z'], zdir='z', s=0.01, c=singleReturns['intens'], cmap='bone', marker='o', depthshade=True)
ax1.scatter3D(multipleReturns['X'], multipleReturns['Y'], multipleReturns['Z'], zdir='z', s=2, c=multipleReturns['Z'], cmap='summer', marker='+', depthshade=True)
ax1.view_init(30, 225)         
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_zticks([])
ax1.grid(False)
ax1.set_axis_off()           
ax1.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.set_xlim3d(xmean-boxSize/2, xmean+boxSize/2)
ax1.set_ylim3d(ymean-boxSize/2, ymean+boxSize/2)
ax1.set_zlim3d(zmean-boxSize/2, zmean+boxSize/2)
plt.show()
# Out:
# 40.673740456347005 -73.9852487204701
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Users/joe/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "/Users/joe/opt/anaconda3/lib/python3.9/tkinter/__init__.py", line 814, in callit
#     func(*args)
#   File "/Users/joe/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/_backend_tk.py", line 252, in idle_draw
#     self.draw()
#   File "/Users/joe/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_tkagg.py", line 9, in draw
#     super().draw()
#   File "/Users/joe/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py", line 431, in draw
#     self.renderer = self.get_renderer(cleared=True)
#   File "/Users/joe/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py", line 447, in get_renderer
#     self.renderer = RendererAgg(w, h, self.figure.dpi)
#   File "/Users/joe/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py", line 93, in __init__
#     self._renderer = _RendererAgg(int(width), int(height), dpi)
# ValueError: Image size of 4500x67500 pixels is too large. It must be less than 2^16 in each direction.

# %%
#experimenting with automatically setting hyperparameters 
points = multipleReturns[['X','Y','Z']].to_numpy()
distances = pdist(points)
try:
    distances = np.reshape(distances,[len(points),-1])
except:
    distances = np.reshape(distances,[len(points)-1,-1])
avgMinDist = np.mean(np.amin(distances,axis=1))
avgDist = np.mean(distances)
stdDist = np.std(distances)
#print(avgDist,stdDist)  
xmin,xmax = multipleReturns['X'].min(),multipleReturns['X'].max()
ymin,ymax = multipleReturns['Y'].min(),multipleReturns['Y'].max()
zmin,zmax = multipleReturns['Z'].min(),multipleReturns['Z'].max()

eps = avgDist**0.33  #len(multipleReturns) / (0.025*(xmax-xmin)*(ymax-ymin)*(zmax-zmin))
clustering = DBSCAN(eps=eps,min_samples=20).fit(points)
clusters = clustering.labels_

multipleReturns['cluster'] = clusters

#print(multipleReturns.head())

###

fig = plt.figure(figsize=(15,15), dpi=300, constrained_layout=True)
ax1 = fig.add_subplot(1, 1, 1, projection='3d') ############         
ax1.scatter3D(singleReturns['X'], singleReturns['Y'], singleReturns['Z'], zdir='z', s=0.01, c='gainsboro', marker='o', depthshade=True)
ax1.scatter3D(multipleReturns['X'], multipleReturns['Y'], multipleReturns['Z'], zdir='z', s=2, c=multipleReturns['cluster'], cmap='tab20', marker='+', depthshade=True)
ax1.view_init(30, 225)        
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_zticks([])
ax1.grid(False)
ax1.set_axis_off()           
ax1.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.set_xlim3d(xmean-boxSize/2, xmean+boxSize/2)
ax1.set_ylim3d(ymean-boxSize/2, ymean+boxSize/2)
ax1.set_zlim3d(zmean-boxSize/2, zmean+boxSize/2)
plt.show()
# Out:
# /var/folders/5j/md25mrks3v1c7ghj1xzvpsb80000gn/T/ipykernel_6548/457682910.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   multipleReturns['cluster'] = clusters

# %%
maxSearch = multipleReturns [multipleReturns['cluster'] != -1]
maxSearch['seeds'] = 1
xs = maxSearch['X'].to_numpy()
ys = maxSearch['Y'].to_numpy()
zs = maxSearch['Z'].to_numpy()
seeds = maxSearch['seeds'].to_numpy()

neighborhood = 4
changes = 1
while changes > 0:
    changes = 0
    i = 0
    for x,y,z,seed in zip(xs,ys,zs,seeds):
        if seed == 1:
            zsearch = zs[xs > x - neighborhood]
            xsearch = xs[xs > x - neighborhood]
            ysearch = ys[xs > x - neighborhood]
            
            zsearch = zsearch[xsearch < x + neighborhood]
            ysearch = ysearch[xsearch < x + neighborhood]
            
            zsearch = zsearch[ysearch > y - neighborhood]
            ysearch = ysearch[ysearch > y - neighborhood]
            
            zsearch = zsearch[ysearch < y + neighborhood]

            zmax = np.max(zsearch)
            if z < zmax:
                seeds[i] = 0
                changes += 1
            else:
                pass
        else:
            pass
        i+=1

maxSearch['seeds'] = seeds      
localMaxima = maxSearch[maxSearch['seeds']>0]

#

centers=localMaxima[['X','Y','Z']].to_numpy()
nbrs = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(centers)
points = maxSearch[['X','Y','Z']].to_numpy()
distances, indices = nbrs.kneighbors(points)
maxSearch['nearestNeighbor'] = indices

#

fig = plt.figure(figsize=(15,15), dpi=300, constrained_layout=True)
ax1 = fig.add_subplot(1, 1, 1, projection='3d') ############         
ax1.scatter3D(singleReturns['X'], singleReturns['Y'], singleReturns['Z'], zdir='z', s=0.005, c='gainsboro', marker='o', depthshade=True)
ax1.scatter3D(maxSearch['X'], maxSearch['Y'], maxSearch['Z'], zdir='z', s=0.11, c=maxSearch['nearestNeighbor'], cmap='tab20', marker='o', depthshade=True)
ax1.scatter3D(localMaxima['X'], localMaxima['Y'], localMaxima['Z'], zdir='z', s=100, c='black', marker='+', depthshade=True)
ax1.view_init(30, 225)        
ax1.set_xticks([])
ax1.set_yticks([])
ax1.set_zticks([])
ax1.grid(False)
ax1.set_axis_off()           
ax1.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.zaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
ax1.set_xlim3d(xmean-boxSize/2, xmean+boxSize/2)
ax1.set_ylim3d(ymean-boxSize/2, ymean+boxSize/2)
ax1.set_zlim3d(zmean-boxSize/2, zmean+boxSize/2)
plt.show()
# Out:
# /var/folders/5j/md25mrks3v1c7ghj1xzvpsb80000gn/T/ipykernel_6548/236384428.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maxSearch['seeds'] = 1
# /var/folders/5j/md25mrks3v1c7ghj1xzvpsb80000gn/T/ipykernel_6548/236384428.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maxSearch['seeds'] = seeds
# /var/folders/5j/md25mrks3v1c7ghj1xzvpsb80000gn/T/ipykernel_6548/236384428.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   maxSearch['nearestNeighbor'] = indices

# %%
# calendar date time picker
pn.extension()
datetime_picker = pn.widgets.DatetimePicker(name='Datetime Picker', value=datetime.datetime(2022, 12, 8, 12, 00))
#datetime_picker.value
datetime_picker
#pn.Row(datetime_picker.controls(jslink=True), datetime_picker)
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# DatetimePicker(name='Datetime Picker', value=datetime.datetime(2022, ...)

# %%
# solar retrieve block

#date = datetime.datetime(year, month, day, hour+4, minute, 0, 0, tzinfo=datetime.timezone.utc)
date = datetime_picker.value
#date = date.replace(tzinfo=datetime.timezone.utc)

tz = tzwhere.tzwhere()
timezone_str = tz.tzNameAt(lat,lon) 
zone = pytz.timezone(timezone_str)
date = zone.localize(date)

az = get_azimuth(lat, lon, date)
amp = get_altitude(lat, lon, date)
rad = radiation.get_radiation_direct(date, amp)
print('Solar details: azimuth {}, amplitude {}, clear sky radiation {}'.format(az,amp,rad))
# Out:
# /Users/joe/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_asarray.py:102: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return array(a, dtype, copy=False, order=order)
# Solar details: azimuth 179.0003349765064, amplitude 24.140650350058962, clear sky radiation 874.2790568077351
# /Users/joe/opt/anaconda3/lib/python3.9/site-packages/pysolar/solartime.py:111: UserWarning: I don't know about leap seconds after 2021
#   warnings.warn \

# %%
#species leaf area index in dense forest settting

lai = 0.75
laiDF = pd.read_csv('lai.csv')
laiDF = laiDF[laiDF['Country'] == 'USA']
speciesList = laiDF['Dominant_species'].unique()

for species in speciesList:
    tempLaiDF = laiDF[laiDF['Dominant_species'] == species]
    speciesLaiMean = tempLaiDF['Corrected_total_LAI_HSA'].mean()
    print('{} leaf area index: {} m2 m-2'.format(species,speciesLaiMean))
# Out:
# Thuja plicata, Pseudotsuga menziesii, Tsuga heterophylla leaf area index: 6.892142857142857 m2 m-2
# Pinus ponderosa leaf area index: 3.397906976744186 m2 m-2
# Adenostoma fasciculatum leaf area index: 1.29 m2 m-2
# Heath; deciduous(35-60%), evergreen(30-60%) leaf area index: 0.5299999999999999 m2 m-2
# Shrub; Deciduous (70-100%), evergreen(0-30%) leaf area index: 1.3266666666666667 m2 m-2
# Betula nana, Eriophorum vaginatum, Sphagnum mosses leaf area index: 2.53 m2 m-2
# Sphagnum mosses, Epriophorum vaginatum, Betual nana leaf area index: 1.22 m2 m-2
# Salix pulchra, Betual nana leaf area index: 3.47 m2 m-2
# Fagus grandifolia, Acer saccharum, Betula alleghaniensis leaf area index: 7.0 m2 m-2
# Quercus douglasii leaf area index: 0.83 m2 m-2
# Iva frutescens leaf area index: 0.84 m2 m-2
# Rhus copallina leaf area index: 1.52 m2 m-2
# Elaeagnus umbellata leaf area index: 5.8 m2 m-2
# Rhododendron maximum leaf area index: 8.36 m2 m-2
# Morella cerifera leaf area index: 9.75 m2 m-2
# Quercus rubra, Carya spp. leaf area index: 6.9 m2 m-2
# Quercus Prinus, Acer rubrum leaf area index: 5.166666666666667 m2 m-2
# Carya spp., Quercus Prinus leaf area index: 5.4 m2 m-2
# Quercus Prinus, Quercus velutina leaf area index: 6.466666666666666 m2 m-2
# Acer rubrum, Carya spp. leaf area index: 5.2 m2 m-2
# Acer rubrum, Quercus Prinus  leaf area index: 5.85 m2 m-2
# Quercus rubra leaf area index: 3.84 m2 m-2
# Quercus Prinus, Liriodendron tulipifera leaf area index: 5.2 m2 m-2
# Quercus prinus leaf area index: 6.325 m2 m-2
# Abies balsamea leaf area index: 5.415000000000001 m2 m-2
# Picea rubens leaf area index: 3.816666666666667 m2 m-2
# Pinus ponderosa, Larix occidentalis, Abies grandis leaf area index: 2.9800000000000004 m2 m-2
# Pinus ponderosa, Larix occidentalis, Pinus contorta, Pesudotsuga menziessii leaf area index: 2.35 m2 m-2
# Pinus ponderosa, Calocedrus decurrens leaf area index: 3.665 m2 m-2
# Pseudotsuga menziesii, Tsuga heterophylla, Thuja plicata leaf area index: 10.255 m2 m-2
# Metrosideros polymorpha leaf area index: 4.658333333333333 m2 m-2
# Eucalyptus saligna leaf area index: 3.1277777777777778 m2 m-2
# Pinus contorta leaf area index: 3.1428358208955216 m2 m-2
# Quercus spp., Acer spp. leaf area index: 4.7172222222222215 m2 m-2
# Pseudotsuga menziesii leaf area index: 8.577399999999999 m2 m-2
# Larix occidentalis, Pinus monticola leaf area index: 4.43 m2 m-2
# Pinus monticola, Larix occidentalis leaf area index: 4.0 m2 m-2
# Abies grandis, Thuja plicata, Pseudotsuga menziesii leaf area index: 5.84 m2 m-2
# Pseudotsuga menziesii, Pinus ponderosa leaf area index: 4.97 m2 m-2
# Pseudotsuga menziesii, Pinus monticola leaf area index: 3.99 m2 m-2
# Sequoia sempervirens leaf area index: 14.374 m2 m-2
# Tsuga heterophylla leaf area index: 17.595 m2 m-2
# Tsuga heterophylla, Pseudotusga menziesii leaf area index: 11.58 m2 m-2
# Abies amabilis leaf area index: 11.63 m2 m-2
# Abies concolor leaf area index: 8.606666666666667 m2 m-2
# Pinus strobus leaf area index: 4.8563636363636355 m2 m-2
# Acacia koa leaf area index: 2.661428571428572 m2 m-2
# Acacia koa, Fraxinus udhei leaf area index: 1.24 m2 m-2
# Quercus alba, Carya tomentosa leaf area index: 5.0 m2 m-2
# Pinus taeda leaf area index: 3.908235294117647 m2 m-2
# Liquidambar styraciflua leaf area index: 5.5 m2 m-2
# Betula nana, Ledum decumbens, Salix pulchra leaf area index: 1.94 m2 m-2
# Alnus, Betual exilis, Salix alaxensis, Salix pulchra leaf area index: 1.6666666666666667 m2 m-2
# Vaccinium uliginosum, Salix lanata spp., Ledum, Empetrum hermaphroditum leaf area index: 1.12 m2 m-2
# Salix spp., Dryas, Arctous alpina, Cassiope, Vaccinium vitis-idaea leaf area index: 0.01 m2 m-2
# Pinus resinosa leaf area index: 4.733333333333333 m2 m-2
# Populus tremuloides leaf area index: 4.65 m2 m-2
# Fraxinus pennsylvanica leaf area index: 3.53 m2 m-2
# Quercus alba, Quercus rubra, Quercus marilandica leaf area index: 6.136363636363637 m2 m-2
# Populus fremontii leaf area index: 3.06 m2 m-2
# Pinus taeda, Liquidambar styraciflua, Liriodendron tulipifera, Ulmus elata, Acer rubrum, Quercus spp., Carya spp. leaf area index: 4.624444444444444 m2 m-2
# Fagus grandifolia, Acer saccharum, Betula alleghaniensis, Acer rubrum, Betula papyrifera leaf area index: 3.6 m2 m-2
# Quercus sp., Carya sp., Acer sp. leaf area index: 6.0 m2 m-2
# Quercus sp., Carya sp. leaf area index: 5.6 m2 m-2
# Acer saccharum, Liriodendron tulipifera, Quercus spp. leaf area index: 5.76 m2 m-2
# Populus grandidentata, Populus tremuloides leaf area index: 4.4 m2 m-2
# Quercus prinus, Quercus velutina, Quercus coccinia leaf area index: 4.05 m2 m-2
# Tsuga mertensiana leaf area index: 5.16 m2 m-2
# Acer rubrum, Acer saccharum, Betula papyrifera, Populus grandidentata, Quercus rubra leaf area index: 4.54 m2 m-2
# Acer saccharum, Tsuga canadensis leaf area index: 6.02 m2 m-2
# Quercus myrtifolia, Quercus geminata, Quercus chapmanii leaf area index: 2.6 m2 m-2
# Quercus rubra, Quercus alba, Quercus velutina leaf area index: 5.88 m2 m-2
# Larix occidentalis, Pinus ponderosa leaf area index: 3.73 m2 m-2
# Pinus ponderosa, Pseudotsuga menziesii leaf area index: 3.25 m2 m-2
# Liriodendron tulipifera, Quercus prinus, Quercus rubra, Quercus alba, Quercus velutina etc.  leaf area index: 8.0625 m2 m-2
# Acer rubrum, Cornus florida, Ilex opaca, Liquidambar styraciflua, Liriodendron tulipifera etc. leaf area index: 6.35 m2 m-2
# Populus deltoides leaf area index: 3.675 m2 m-2
# Tamarix chinensis, Distichlis spicata leaf area index: 1.44 m2 m-2
# Tamarix chinensis leaf area index: 2.85 m2 m-2
# Vaccinium uliginosum, evergreen shrub leaf area index: 0.61 m2 m-2
# Betula glandulosa, Vaccinium uliginosum leaf area index: 2.0 m2 m-2
# Betula glandulosa, Salix spp. leaf area index: 2.22 m2 m-2
# Betula glandulosa, Salix spp., Picea glauca leaf area index: 2.67 m2 m-2
# Picea glauca leaf area index: 5.68 m2 m-2
# Pinus elliottii leaf area index: 2.47 m2 m-2
# Liriodendron tulipifera, Fagus grandifolia, Carya tomentosa leaf area index: 7.0 m2 m-2
# Diospyros sandwicensis, Psydrax odorata leaf area index: 2.475 m2 m-2
# Abies lasiocarpa leaf area index: 8.315 m2 m-2
# Acer rubrum leaf area index: 5.97 m2 m-2
# Quercus rubra, Quercus prinus leaf area index: 1.88 m2 m-2
# Quercus prinus, Quercus spp. leaf area index: 2.72 m2 m-2
# Quercus prinus, Quercus florida leaf area index: 3.28 m2 m-2
# Quercus rubra, Quercus alba, Quercus prinus, Quercus velutina leaf area index: 4.0 m2 m-2
# Quercus ellipsoidalis, Quercus macrocarpa leaf area index: 3.254 m2 m-2
# Pinus contorta, Pinus monticola, Abies magnifica, Tsuga mertensiana leaf area index: 2.84 m2 m-2
# Toona ciliata leaf area index: 2.94 m2 m-2
# Acacia Koa, Toona ciliata leaf area index: 2.94 m2 m-2
# Acer saccharum leaf area index: 4.96 m2 m-2
# Tsuga canadensis leaf area index: 5.05 m2 m-2
# Tsuga canadensis, Picea rubens leaf area index: 3.2 m2 m-2
# Picea rubens, Betula papyrifera leaf area index: 2.77 m2 m-2
# Pinus strobus, hardwood mixtures leaf area index: 4.24 m2 m-2
# Fagus grandifolia leaf area index: 4.2075 m2 m-2
# Fagus grandifolia, Quercus rubra leaf area index: 3.33 m2 m-2
# Betula papyrifera, Fagus grandifolia leaf area index: 3.39 m2 m-2
# Quercus rubra, Fagus grandifolia leaf area index: 3.35 m2 m-2
# Acer saccharum, Fagus grandifolia leaf area index: 3.48 m2 m-2
# Acer saccharum, Fraxinus americana leaf area index: 3.47 m2 m-2
# Pinus banksiana leaf area index: 2.18 m2 m-2
# Pinus resinosa, Populus tremuloides leaf area index: 4.64 m2 m-2
# Quercus rubra, Pinus resinosa, Acer rubrum leaf area index: 5.0 m2 m-2
# Populus tremuloides, Acer rubrum, Quercus rubra, Populus grandidentata leaf area index: 4.4 m2 m-2
# Pinus resinosa, Pinus strobus, Acer rubrum leaf area index: 6.09 m2 m-2
# Acer saccharum, Betula papyrifera, Pinus strobus leaf area index: 5.1 m2 m-2
# Acer saccharum, Quercus rubra, Betula papyrifera leaf area index: 5.9 m2 m-2
# Quercus rubra, Acer saccharum, Acer rubrum leaf area index: 5.6 m2 m-2
# Quercus rubra, Acer rubrum leaf area index: 5.5 m2 m-2
# Acer saccharum, Acer rubrum, Tsuga canadensis leaf area index: 6.8 m2 m-2
# Acer saccharum, Tilia americana leaf area index: 6.3 m2 m-2
# Betula papyrifera, Acer saccharum, Populus tremuloides leaf area index: 5.9 m2 m-2
# Acer saccharum, Betula alleghaniensis leaf area index: 6.3 m2 m-2
# Acer saccharum, Tilia americana, Populus tremuloides leaf area index: 8.0 m2 m-2
# Acer saccharum, Fraxinus spp., Quercus rubra leaf area index: 8.4 m2 m-2
# Acer saccharum, Tilia americana, Fraxinus spp. leaf area index: 5.1 m2 m-2
# Pinus elliotti leaf area index: 3.0 m2 m-2
# Pseudotsuga menziesii, Abies grandis leaf area index: 9.0 m2 m-2
# Pseudotsuga menziesii, Tsuga heterophylla, Abies amabilis leaf area index: 11.0 m2 m-2
# Juniperus occidentalis leaf area index: 0.73 m2 m-2
# Artemisia tridentata leaf area index: 0.5 m2 m-2
# Mixed hardwood forest leaf area index: 5.975 m2 m-2
# Larix decidua leaf area index: 5.87 m2 m-2
# Picea abies leaf area index: 3.0942424242424234 m2 m-2
# Picea sitchensis, Tsuga heterophylla leaf area index: 6.1 m2 m-2
# Alnus rubra leaf area index: 5.545 m2 m-2
# Tsuga mertensiana, Pseudotsuga menziesii leaf area index: 10.01 m2 m-2
# Tsuga heterophylla, Pseudotsuga menziesii leaf area index: 9.55 m2 m-2
# Picea engelmannii leaf area index: 4.72 m2 m-2
# Abies grandis leaf area index: 6.1 m2 m-2
# Abies concolor, Pseudotsuga menziesii leaf area index: 7.75 m2 m-2
# Pinus ponderosa, Pinus strobiformis leaf area index: 3.8 m2 m-2
# Pinus chihuahuana, Pinus ponderosa, Quercus hypoleucoides, Quercus arizonica leaf area index: 1.85 m2 m-2
# Pinus cembroides, Juniperus deppeana leaf area index: 1.0 m2 m-2
# Quercus oblongifolia, Quercus emoryi leaf area index: 1.76 m2 m-2
# Fouquieria splendens, Prosopis juliflora et al. leaf area index: 1.58 m2 m-2
# Carnegiea gigantea, Cercidium microphyllum, Fouquieria splendens leaf area index: 0.94 m2 m-2
# Cercidium microphyllum, Franseria deltoidea, Fouquieria splendens leaf area index: 0.59 m2 m-2
# Larrea divaricata leaf area index: 0.6 m2 m-2
# Cercocarpus breviflorus leaf area index: 1.4 m2 m-2
# Aesculus octandra leaf area index: 6.2 m2 m-2
# Pinus (heath) leaf area index: 2.35 m2 m-2
# Pinus echinata leaf area index: 3.9 m2 m-2
# Abies fraseri leaf area index: 6.15 m2 m-2
# Liriodendron tulipifera leaf area index: 6.65 m2 m-2
# Quercus rubra, Quercus alba leaf area index: 3.5 m2 m-2
# Deschampsia flexuosa, Leiophyllum lyoni leaf area index: 0.08 m2 m-2
# Leiophyllum lyoni leaf area index: 3.1 m2 m-2
# Rhododendron carolinianum leaf area index: 2.0 m2 m-2
# Rhododendron catawbiense leaf area index: 2.8 m2 m-2
# Rhododendron catawbiense, Kalmia latifolia, Gaylyssacia baccata leaf area index: 1.97 m2 m-2
# Rhododendron catawbiense, Kalmia latifolia leaf area index: 3.9666666666666663 m2 m-2
# Rhododendron catawbiense, Gaylyssacia baccata leaf area index: 6.08 m2 m-2
# Fagus grandifolia, Acer saccharum, Betula lutea leaf area index: 5.85 m2 m-2
# Acer saccharum, Betula lutea, Fagus grandifolia leaf area index: 5.7 m2 m-2
# Pinus edulis, Juniperus monosperma leaf area index: 2.0 m2 m-2
# Quercus spps, Acer rubrum, Liriodendron tulifpifera  leaf area index: 4.9 m2 m-2
# Salix spp., Betula nana etc. leaf area index: 0.8049999999999999 m2 m-2
# Salix glauca, Salix planifolia, Betula nana, Eriophorum angustifolium leaf area index: 2.46 m2 m-2
# Populus tremuloides, Populus grandidentata leaf area index: 3.550606060606061 m2 m-2
# Quercus alba, Quercus coccinea leaf area index: 3.79 m2 m-2
# Atriplex confertifolia leaf area index: 2.12 m2 m-2
# Atriplex lentiformis (Torr.) leaf area index: 2.82 m2 m-2
# Atriplex canescens leaf area index: 2.99 m2 m-2
# Sarcobatus vermiculatus leaf area index: 2.22 m2 m-2
# Chrysothamnus consimilis leaf area index: 2.02 m2 m-2
# Artemesia tridentata leaf area index: 1.25 m2 m-2
# Populus tremuloides, Betula papyrifera, Acer rubrum leaf area index: 4.9 m2 m-2
# Populus tremuloides, Betula papyrifera, Acer rubrum. Acer saccharum leaf area index: 5.5 m2 m-2
# Quercus prinus, Cornus florida, Quercus alba leaf area index: 2.7 m2 m-2
# Quercus alba, Cornus florida leaf area index: 3.4 m2 m-2
# Quercus prinus, Cornus florida, Quercus velutina leaf area index: 2.9 m2 m-2
# Acer saccharum, Quercus prinus, Cornus florida leaf area index: 3.0 m2 m-2
# Quercus alba, Quercus velutina, Fagus grandifolia leaf area index: 3.0 m2 m-2
# Quercus alba, Acer rubrum, Fagus grandifolia, Quercus velutina leaf area index: 3.3 m2 m-2
# Fagus grandifolia, Acer saccharum leaf area index: 3.95 m2 m-2
# Fagus grandifolia, Acer saccharum, Quercus velutina, Cornus florida leaf area index: 4.0 m2 m-2
# Taxodium distichum leaf area index: 1.015 m2 m-2
# Taxodium distichum, Nyssa biflora leaf area index: 3.5 m2 m-2
# Taxodium distichum, Fraxinus caroliniana leaf area index: 9.14 m2 m-2
# Populus grandidentata, Acer rubrum, Quercus rubra, Populus tremuloides leaf area index: 3.59 m2 m-2
# Populus grandidentata, Acer rubrum, Quercus rubra leaf area index: 2.9 m2 m-2
# Populus grandidentata leaf area index: 2.43 m2 m-2
# Populus balsamifera, Alnus tenuifolia leaf area index: 3.0 m2 m-2
# Populus balsamifera leaf area index: 6.0 m2 m-2
# Betula papyrifera, Populus tremuloides leaf area index: 4.0 m2 m-2
# Abies magnifica, Abies concolor leaf area index: 8.01 m2 m-2
# Abies magnifica leaf area index: 10.67 m2 m-2
# Picea engelmannii, Abies lasiocarpa leaf area index: 10.176666666666666 m2 m-2
# Quercus stellata, Quercus marilandica leaf area index: 4.8 m2 m-2
# Quercus alba leaf area index: 4.0 m2 m-2
# Cupressus pygmaea, Vaccinium ovatum, Pinus contorta leaf area index: 1.91 m2 m-2
# Evergreen and deciduous shrub, Graminoids leaf area index: 1.2 m2 m-2
# Salix spp. leaf area index: 1.39 m2 m-2
# Evergreen shrub (L. palustre, V vitis-ideaea, E. nigrum, L. procumbens) leaf area index: 0.18 m2 m-2
# Prunus pensylvanica leaf area index: 5.733333333333334 m2 m-2
# Carya tomentosa, Liriodendron tulipifera leaf area index: 4.7 m2 m-2
# Pinus contorta, Larix occidentalis, Pseudotsuga menziesii, Abies grandis leaf area index: 4.83 m2 m-2

# %%
#converting solar azimuth and amplitude to a vector normal 

solarX = math.cos(amp) * math.cos(-az)  
solarY = math.cos(amp) * math.sin(-az) 
solarZ = -math.sin(amp) 
#print(solarX,solarY,solarZ)

# define a function to calculate the equation of a plane given a normal vector
def plane_equation(normal,x=1,y=1,z=1):
  a, b, c = normal
  d = -(a * x + b * y + c * z)
  return a, b, c, d

# define a function to project a 3D point onto a plane
def project_point(point, plane_equation):
  # unpack the point coordinates
  x, y, z = point
  a, b, c, d = plane_equation
  # calculate the distance from the point to the plane
  distance = abs(a * x + b * y + c * z + d) / math.sqrt(a**2 + b**2 + c**2)
  # calculate the coordinates of the projection of the point onto the plane
  x_proj = x - a * distance
  y_proj = y - b * distance
  z_proj = z - c * distance
  # return the coordinates of the projected point
  return x_proj, y_proj, z_proj

# define a function to calculate the area of a 2D shape
def area_2d(points):
  # calculate the area of the 2D shape
  # using the Shoelace formula
  x_sum = 0
  y_sum = 0
  for i in range(len(points)):
    x, y, z = points[i]
    x_next, y_next, z_next = points[(i + 1) % len(points)]
    x_sum += x * y_next
    y_sum += y * x_next
  area = 0.5 * abs(x_sum - y_sum)
  
  # return the area
  return area

# define a normal vector for the plane
normal = (solarX,solarY,solarZ)
# calculate the equation of the plane
plane_equation = plane_equation(normal)

clusters = maxSearch['nearestNeighbor'].unique()
#clusters = clusters[clusters>=0]

for cluster in clusters:
    temp = maxSearch[maxSearch['nearestNeighbor'] == cluster]
    points = temp[['X','Y','Z']].to_numpy()
    # project the 3D points onto the plane
    projected_points = [project_point(point, plane_equation) for point in points]
    # calculate the area of the 2D shape formed by the projected points
    area = area_2d(projected_points)*0.0929
    watts = area * rad * lai
    # print the area
    print('Cluster {}: \n{} square meters \n{} watts clear sky radiation blocked \n'.format(cluster,area,watts))
# Out:
# Cluster 105:
# 1.927675 square meters
# 1263.9944106238881 watts clear sky radiation blocked
#
# Cluster 4:
# 11.7054 square meters
# 7675.339553667945 watts clear sky radiation blocked
#
# Cluster 81:
# 8.6397 square meters
# 5665.131575326341 watts clear sky radiation blocked
#
# Cluster 93:
# 1.13221875 square meters
# 742.4063556375246 watts clear sky radiation blocked
#
# Cluster 108:
# 8.151975 square meters
# 5345.325760590177 watts clear sky radiation blocked
#
# Cluster 117:
# 8.1752 square meters
# 5360.554608910947 watts clear sky radiation blocked
#
# Cluster 0:
# 0.058062499999999996 square meters
# 38.072120801924335 watts clear sky radiation blocked
#
# Cluster 58:
# 0.9289999999999999 square meters
# 609.1539328307894 watts clear sky radiation blocked
#
# Cluster 1:
# 6.3172 square meters
# 4142.246743249368 watts clear sky radiation blocked
#
# Cluster 11:
# 1.2599562499999999 square meters
# 826.1650214017582 watts clear sky radiation blocked
#
# Cluster 116:
# 11.84475 square meters
# 7766.712643592565 watts clear sky radiation blocked
#
# Cluster 61:
# 8.50035 square meters
# 5573.758485401722 watts clear sky radiation blocked
#
# Cluster 22:
# 42.2695 square meters
# 27716.50394380092 watts clear sky radiation blocked
#
# Cluster 7:
# 1.90445 square meters
# 1248.7655623031183 watts clear sky radiation blocked
#
# Cluster 2:
# 4.9237 square meters
# 3228.5158440031837 watts clear sky radiation blocked
#
# Cluster 49:
# 4.31985 square meters
# 2832.5657876631703 watts clear sky radiation blocked
#
# Cluster 5:
# 0.69675 square meters
# 456.865449623092 watts clear sky radiation blocked
#
# Cluster 112:
# 17.8368 square meters
# 11695.755510351157 watts clear sky radiation blocked
#
# Cluster 3:
# 3.5302 square meters
# 2314.7849447569997 watts clear sky radiation blocked
#
# Cluster 8:
# 6.08495 square meters
# 3989.9582600416707 watts clear sky radiation blocked
#
# Cluster 71:
# 0.069675 square meters
# 45.686544962309206 watts clear sky radiation blocked
#
# Cluster 55:
# 3.1121499999999997 square meters
# 2040.665674983144 watts clear sky radiation blocked
#
# Cluster 64:
# 1.602525 square meters
# 1050.7905341331116 watts clear sky radiation blocked
#
# Cluster 118:
# 1.974125 square meters
# 1294.4521072654275 watts clear sky radiation blocked
#
# Cluster 25:
# 6.990724999999999 square meters
# 4583.88334455169 watts clear sky radiation blocked
#
# Cluster 79:
# 3.01925 square meters
# 1979.7502817000654 watts clear sky radiation blocked
#
# Cluster 35:
# 4.31985 square meters
# 2832.5657876631703 watts clear sky radiation blocked
#
# Cluster 91:
# 5.24885 square meters
# 3441.7197204939603 watts clear sky radiation blocked
#
# Cluster 115:
# 22.52825 square meters
# 14771.982871146642 watts clear sky radiation blocked
#
# Cluster 31:
# 17.7439 square meters
# 11634.840117068077 watts clear sky radiation blocked
#
# Cluster 13:
# 12.21635 square meters
# 8010.374216724881 watts clear sky radiation blocked
#
# Cluster 68:
# 2.9844125 square meters
# 1956.9070092189108 watts clear sky radiation blocked
#
# Cluster 77:
# 28.56675 square meters
# 18731.48343454677 watts clear sky radiation blocked
#
# Cluster 21:
# 0.23224999999999998 square meters
# 152.28848320769734 watts clear sky radiation blocked
#
# Cluster 44:
# 0.41224374999999996 square meters
# 270.3120576936628 watts clear sky radiation blocked
#
# Cluster 75:
# 13.934999999999999 square meters
# 9137.30899246184 watts clear sky radiation blocked
#
# Cluster 28:
# 14.5853 square meters
# 9563.716745443395 watts clear sky radiation blocked
#
# Cluster 38:
# 1.16125 square meters
# 761.4424160384867 watts clear sky radiation blocked
#
# Cluster 97:
# 10.567375 square meters
# 6929.12598595023 watts clear sky radiation blocked
#
# Cluster 20:
# 0.580625 square meters
# 380.72120801924336 watts clear sky radiation blocked
#
# Cluster 83:
# 8.2681 square meters
# 5421.470002194026 watts clear sky radiation blocked
#
# Cluster 39:
# 7.8965 square meters
# 5177.80842906171 watts clear sky radiation blocked
#
# Cluster 82:
# 2.020575 square meters
# 1324.909803906967 watts clear sky radiation blocked
#
# Cluster 42:
# 27.0339 square meters
# 17726.37944537597 watts clear sky radiation blocked
#
# Cluster 40:
# 1.06835 square meters
# 700.5270227554078 watts clear sky radiation blocked
#
# Cluster 41:
# 8.31455 square meters
# 5451.927698835566 watts clear sky radiation blocked
#
# Cluster 59:
# 38.04255 square meters
# 24944.853549420823 watts clear sky radiation blocked
#
# Cluster 86:
# 1.71865 square meters
# 1126.9347757369603 watts clear sky radiation blocked
#
# Cluster 48:
# 18.9516 square meters
# 12426.740229748102 watts clear sky radiation blocked
#
# Cluster 89:
# 13.42405 square meters
# 8802.274329404907 watts clear sky radiation blocked
#
# Cluster 67:
# 1.9392874999999998 square meters
# 1271.6088347842729 watts clear sky radiation blocked
#
# Cluster 6:
# 2.7057124999999997 square meters
# 1774.160829369674 watts clear sky radiation blocked
#
# Cluster 9:
# 5.643675 square meters
# 3700.610141947046 watts clear sky radiation blocked
#
# Cluster 29:
# 2.949575 square meters
# 1934.0637367377562 watts clear sky radiation blocked
#
# Cluster 23:
# 6.36365 square meters
# 4172.704439890907 watts clear sky radiation blocked
#
# Cluster 110:
# 5.2024 square meters
# 3411.2620238524205 watts clear sky radiation blocked
#
# Cluster 60:
# 15.514299999999999 square meters
# 10172.870678274183 watts clear sky radiation blocked
#
# Cluster 26:
# 0.348375 square meters
# 228.432724811546 watts clear sky radiation blocked
#
# Cluster 90:
# 6.526225 square meters
# 4279.306378136296 watts clear sky radiation blocked
#
# Cluster 66:
# 0.859325 square meters
# 563.4673878684802 watts clear sky radiation blocked
#
# Cluster 30:
# 2.2992749999999997 square meters
# 1507.6559837562036 watts clear sky radiation blocked
#
# Cluster 69:
# 1.5212375 square meters
# 997.4895650104177 watts clear sky radiation blocked
#
# Cluster 76:
# 7.5249 square meters
# 4934.146855929394 watts clear sky radiation blocked
#
# Cluster 109:
# 9.406125 square meters
# 6167.683569911742 watts clear sky radiation blocked
#
# Cluster 12:
# 2.577975 square meters
# 1690.4021636054404 watts clear sky radiation blocked
#
# Cluster 106:
# 11.28735 square meters
# 7401.220283894092 watts clear sky radiation blocked
#
# Cluster 54:
# 28.8919 square meters
# 18944.68731103755 watts clear sky radiation blocked
#
# Cluster 36:
# 0.9173874999999999 square meters
# 601.5395086704045 watts clear sky radiation blocked
#
# Cluster 72:
# 4.5521 square meters
# 2984.8542708708683 watts clear sky radiation blocked
#
# Cluster 34:
# 7.176525 square meters
# 4705.7141311178475 watts clear sky radiation blocked
#
# Cluster 103:
# 23.039199999999997 square meters
# 15107.017534203575 watts clear sky radiation blocked
#
# Cluster 52:
# 1.4399499999999998 square meters
# 944.1885958877234 watts clear sky radiation blocked
#
# Cluster 18:
# 2.020575 square meters
# 1324.909803906967 watts clear sky radiation blocked
#
# Cluster 101:
# 2.46185 square meters
# 1614.2579220015919 watts clear sky radiation blocked
#
# Cluster 113:
# 1.2077 square meters
# 791.9001126800263 watts clear sky radiation blocked
#
# Cluster 62:
# 19.36965 square meters
# 12700.859499521957 watts clear sky radiation blocked
#
# Cluster 57:
# 5.597225 square meters
# 3670.1524453055063 watts clear sky radiation blocked
#
# Cluster 102:
# 5.4346499999999995 square meters
# 3563.5505070601175 watts clear sky radiation blocked
#
# Cluster 10:
# 7.9777875 square meters
# 5231.109398184404 watts clear sky radiation blocked
#
# Cluster 92:
# 0.6619125 square meters
# 434.02217714193745 watts clear sky radiation blocked
#
# Cluster 63:
# 1.3818875 square meters
# 906.1164750857992 watts clear sky radiation blocked
#
# Cluster 111:
# 0.6735249999999999 square meters
# 441.6366013023222 watts clear sky radiation blocked
#
# Cluster 114:
# 1.2657625 square meters
# 829.9722334819505 watts clear sky radiation blocked
#
# Cluster 84:
# 5.9456 square meters
# 3898.585170117052 watts clear sky radiation blocked
#
# Cluster 98:
# 0.9173874999999999 square meters
# 601.5395086704045 watts clear sky radiation blocked
#
# Cluster 96:
# 1.1264125 square meters
# 738.5991435573321 watts clear sky radiation blocked
#
# Cluster 14:
# 1.8347749999999998 square meters
# 1203.079017340809 watts clear sky radiation blocked
#
# Cluster 94:
# 0.60385 square meters
# 395.95005634001313 watts clear sky radiation blocked
#
# Cluster 24:
# 0.88255 square meters
# 578.6962361892499 watts clear sky radiation blocked
#
# Cluster 70:
# 0.4528875 square meters
# 296.96254225500985 watts clear sky radiation blocked
#
# Cluster 119:
# 2.1483125 square meters
# 1408.6684696712005 watts clear sky radiation blocked
#
# Cluster 47:
# 41.688874999999996 square meters
# 27335.78273578167 watts clear sky radiation blocked
#
# Cluster 73:
# 0.22644375 square meters
# 148.48127112750493 watts clear sky radiation blocked
#
# Cluster 33:
# 5.875925 square meters
# 3852.898625154743 watts clear sky radiation blocked
#
# Cluster 107:
# 5.759799999999999 square meters
# 3776.7543835508936 watts clear sky radiation blocked
#
# Cluster 53:
# 6.851375 square meters
# 4492.510254627072 watts clear sky radiation blocked
#
# Cluster 16:
# 1.3818875 square meters
# 906.1164750857992 watts clear sky radiation blocked
#
# Cluster 78:
# 1.06835 square meters
# 700.5270227554078 watts clear sky radiation blocked
#
# Cluster 17:
# 15.165925 square meters
# 9944.437953462637 watts clear sky radiation blocked
#
# Cluster 45:
# 1.788325 square meters
# 1172.6213206992697 watts clear sky radiation blocked
#
# Cluster 15:
# 1.4980125 square meters
# 982.2607166896478 watts clear sky radiation blocked
#
# Cluster 87:
# 0.9754499999999999 square meters
# 639.6116294723288 watts clear sky radiation blocked
#
# Cluster 32:
# 0.88255 square meters
# 578.6962361892499 watts clear sky radiation blocked
#
# Cluster 104:
# 1.62575 square meters
# 1066.0193824538815 watts clear sky radiation blocked
#
# Cluster 19:
# 2.92635 square meters
# 1918.8348884169864 watts clear sky radiation blocked
#
# Cluster 65:
# 0.60385 square meters
# 395.95005634001313 watts clear sky radiation blocked
#
# Cluster 80:
# 1.7418749999999998 square meters
# 1142.16362405773 watts clear sky radiation blocked
#
# Cluster 100:
# 17.69745 square meters
# 11604.382420426537 watts clear sky radiation blocked
#
# Cluster 27:
# 2.020575 square meters
# 1324.909803906967 watts clear sky radiation blocked
#
# Cluster 88:
# 2.4850749999999997 square meters
# 1629.4867703223613 watts clear sky radiation blocked
#
# Cluster 85:
# 1.16125 square meters
# 761.4424160384867 watts clear sky radiation blocked
#
# Cluster 37:
# 2.4037875 square meters
# 1576.1858011996678 watts clear sky radiation blocked
#
# Cluster 74:
# 0.1974125 square meters
# 129.44521072654274 watts clear sky radiation blocked
#
# Cluster 56:
# 2.5082999999999998 square meters
# 1644.7156186431312 watts clear sky radiation blocked
#
# Cluster 99:
# 1.5909125 square meters
# 1043.1761099727269 watts clear sky radiation blocked
#
# Cluster 46:
# 3.9250249999999998 square meters
# 2573.675366210085 watts clear sky radiation blocked
#
# Cluster 51:
# 2.0786375 square meters
# 1362.9819247088915 watts clear sky radiation blocked
#
# Cluster 50:
# 0.0812875 square meters
# 53.30096912269407 watts clear sky radiation blocked
#
# Cluster 95:
# 0.301925 square meters
# 197.97502817000657 watts clear sky radiation blocked
#
# Cluster 43:
# 0.1045125 square meters
# 68.52981744346381 watts clear sky radiation blocked
